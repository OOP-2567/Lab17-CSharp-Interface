// %% [markdown]
// # Lab 17 Exercise 5

// %% [markdown]
// ## Implement added interface

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab17_Ex05
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// Animal[] animals = new Animal[3];
// animals[0] = new Dog();
// animals[1] = new Bird();
// animals[2] = new Fish();
//
// foreach (var animal in animals)
// {
//     animal.Move();
//     animal.Speak();
//     System.Console.WriteLine("-------");
// }
//
// interface IMovable
// {
//     public void Move();
// }
// interface ISpeakable
// {
//     public void Speak();
// }
//
// abstract class Animal : IMovable, ISpeakable
// {
//     abstract public void Move();
//     abstract public void Speak();
// }
// class Dog : Animal
// {
//     public override void Move()
//     {
//         System.Console.WriteLine("Dog move by running on the ground");
//     }
//     public override void Speak()
//     {
//         System.Console.WriteLine(@"Dog speak ""Bok Bok""");
//     }
// }
// class Fish : Animal
// {
//     public override void Move()
//     {
//         System.Console.WriteLine("Fish move by swimming in the water");
//     }
//     public override void Speak()
//     {
//         System.Console.WriteLine("Fish can not speak");
//     }
// }
// class Bird : Animal
// {
//     public override void Move()
//     {
//         System.Console.WriteLine("Bird move by flying in the air");
//     }
//     public override void Speak()
//     {
//         System.Console.WriteLine(@"Bird speak ""Jib Jib""");
//     }
// }
//
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab17_Ex05
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab17_Ex05
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// Polymorphism: การสร้างอาร์เรย์ชนิด Animal ที่ประกอบด้วยอ็อบเจกต์ของคลาสลูก (Dog, Bird, Fish) แล้วเรียกใช้เมธอด Move() และ Speak() ผ่านการวนลูป ทำให้เกิดพฤติกรรมที่แตกต่างกันตามชนิดของสัตว์
//
// Override: คลาสลูกได้ Override เมธอด Move() และ Speak() ของคลาสแม่ Animal ทำให้เรียกใช้เมธอดตามชนิดของสัตว์ได้อย่างถูกต้อง
//
// Interface: การใช้ IMovable และ ISpeakable บังคับให้คลาส Animal ต้องอิมพลีเมนต์เมธอด Move() และ Speak() ช่วยให้โครงสร้างโปรแกรมยืดหยุ่นและขยายได้ง่าย
